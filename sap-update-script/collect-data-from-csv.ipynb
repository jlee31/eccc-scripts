# %%
import pandas as pd

ewaste = pd.read_csv("ewaste.csv")
ewaste.head()

# %%
name_list = ewaste['11 - DOE#'].tolist()
name_list

# %%
import json

with open("my_list-ewaste.json", "w") as f:
    json.dump(name_list, f)

# %%
cfs = pd.read_csv("recorded-scripts/cfs.csv")
cfs.head()

# %%
cfslst = cfs['11 - DOE#'].tolist()
cfslst

# %%
import json

with open("my_list_cfs.json", "w") as f:
    json.dump(name_list, f)
